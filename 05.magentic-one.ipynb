# %% [markdown]
# ## Magentic One
#
# ![magentic](https://www.microsoft.com/en-us/research/uploads/prod/2024/11/magnetic_example-2048x1155.png)

# %% [markdown]
# ### What is Magentic One?
# **Magentic One**은 파일/웹 탐색, 코드 작성, 실행/검증을 하나의 팀으로 묶어
# **자율적으로 목표를 달성**하도록 설계된 멀티에이전트 오케스트레이션입니다.
#
# - **FileSurfer**: 파일/로컬 컨텍스트 탐색
# - **MultimodalWebSurfer**: 웹·이미지 등 멀티모달 검색/스크랩
# - **Coder**: 코드 작성/수정
# - **Executor**: 코드 실행/검증
# - (옵션) **UserProxyAgent**: `hil_mode=True` 시 Human-in-the-loop
#
# ---

# %% [markdown]
# ### `magentic_one.py` core code
#
# ```python
# def __init__(self, client: ChatCompletionClient, hil_mode: bool = False):
#     self.client = client
#     self._validate_client_capabilities(client)
#
#     fs = FileSurfer("FileSurfer", model_client=client)
#     ws = MultimodalWebSurfer("WebSurfer", model_client=client)
#     coder = MagenticOneCoderAgent("Coder", model_client=client)
#     executor = CodeExecutorAgent("Executor", code_executor=LocalCommandLineCodeExecutor())
#     agents: List[ChatAgent] = [fs, ws, coder, executor]
#     if hil_mode:
#         user_proxy = UserProxyAgent("User")
#         agents.append(user_proxy)
#     super().__init__(agents, model_client=client)
#
# ```

# %%
# Autonomously complete a coding task:
import asyncio
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_ext.teams.magentic_one import MagenticOne
from autogen_agentchat.ui import Console

from dotenv import load_dotenv
import os

load_dotenv()

api_version = os.getenv("AZURE_OPENAI_API_VERSION")
api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_openai_chat_completion_client = AzureOpenAIChatCompletionClient(
            model=deployment_name,
            azure_endpoint=azure_endpoint,
            api_version=api_version,
            api_key=api_key,
        )


client = azure_openai_chat_completion_client
m1 = MagenticOne(client=client)
task = "마이크로소프트 현재 주가와 전망에 대해 알려줘"
result = await Console(m1.run_stream(task=task))
print(result)
# Out:
# /tmp/ipykernel_98914/3377041901.py:25: DeprecationWarning: Instantiating MagenticOne without a code_executor is deprecated. Provide a code_executor to clear this warning (e.g., code_executor=LocalCommandLineCodeExecutor() ).
#   m1 = MagenticOne(client=client)
# ---------- TextMessage (user) ----------
# 마이크로소프트 현재 주가와 전망에 대해 알려줘
# ---------- TextMessage (MagenticOneOrchestrator) ----------
#
# We are working to address the following user request:
#
# 마이크로소프트 현재 주가와 전망에 대해 알려줘
#
#
# To answer this request we have assembled the following team:
#
# FileSurfer: An agent that can handle local files.
# WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
# Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
# ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
# - The request asks for the current stock price ("현재 주가") of Microsoft ("마이크로소프트") and its outlook ("전망").
# - No specific numbers or dates are provided in the request itself.
#
# 2. FACTS TO LOOK UP
# - The current stock price of Microsoft (ticker symbol MSFT), which can be found on financial news websites such as Yahoo Finance, Google Finance, Bloomberg, or stock exchange official sites (e.g., NASDAQ).
# - Recent analyst reports, news, and forecasts about Microsoft's future outlook, which might be found on financial analysis platforms such as Bloomberg, Morningstar, Seeking Alpha, or reports from major investment banks or research firms.
#
# 3. FACTS TO DERIVE
# - Potential short- to mid-term stock price trends or outlook based on recent performance, market conditions, and company fundamentals.
# - Interpretation of how broader market or sector trends impact Microsoft's prospects.
#
# 4. EDUCATED GUESSES
# - Microsoft is a major technology company with a diversified product portfolio including cloud computing (Azure), software (Windows, Office), gaming (Xbox), and enterprise services. Its stock price is generally influenced by these factors as well as macroeconomic conditions.
# - The outlook might consider the increasing cloud market demand and competitive pressures.
# - Given the dynamic nature of stock markets, the outlook often includes some degree of uncertainty.
#
#
# Here is the plan to follow as best as possible:
#
# - Instruct WebSurfer to look up the current stock price of Microsoft (MSFT) on a reliable financial website (e.g., Yahoo Finance or Google Finance).
# - Ask WebSurfer to gather recent analyst reports, news articles, and expert commentary regarding Microsoft’s future outlook and growth prospects.
# - Have WebSurfer summarize the key points about Microsoft’s market position, recent financial performance, and relevant industry trends affecting its outlook.
# - Synthesize the gathered current price and outlook information into a concise response in Korean, as the original request language is Korean.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please look up the current stock price of Microsoft (MSFT) on a reliable financial website and find recent analyst or expert commentary regarding Microsoft’s stock outlook and future prospects. Summarize the key information.
# ---------- MultiModalMessage (WebSurfer) ----------
# I typed 'Microsoft MSFT stock price and analysis' into the browser search bar.
#
# The web browser is open to the page [Microsoft MSFT stock price and analysis - 검색](https://www.bing.com/search?q=Microsoft+MSFT+stock+price+and+analysis&FORM=QBLH).
# The viewport shows 29% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# 콘텐츠로 건너뛰기
# Microsoft MSFT stock price and analysis3
# 검색
# 이미지
# 동영상
# 지도
# 뉴스
# Copilot
# 더 보기
# 도구
# Microsoft Corp
# NASDAQ: MSFT
# 요약
# 차트
# 재무 정보
# 분석
# 수익
# 비교
# Yahoo Finance
# https://finance.yahoo.com › quote › MSFT
# 이 결과를 번역하세요
# Microsoft Corporation (MSFT) Stock Price, News, Quote & HistoryFind the latest
# Microsoft Corporation (
# MSFT)
# stock quote, history, news and other vital information to help you with your
# stock trading and investing.
# News
# Get the latest Microsoft Corporation (MSFT) stock news and headlines to hel…
# Chart
# Interactive Chart for Microsoft Corporation (MSFT), analyze all the dat…
# Statistics
# Find out all the key statistics for Microsoft Corporation (MSFT), includin…
# ARM
# Find the latest Arm Holdings plc (ARM) stock quote, history, news and other vita…
# ORCL Oracle Corporation
# Find the latest Oracle Corporation (ORCL) stock quote, history, news and other vita…
# Historical Data
# Discover historical prices for MSFT stock on Yahoo! Finance. View daily, weekly or …
# 마이크로소프트 - Wikipedia
# 미국의 다국적 소프트웨어 및 하드웨어 기업
# 마이크로소프트는 컴퓨팅 파워를 지원해주는 클라우드 컴퓨팅 사업을 중심으로, 기업들의 사업을 디지털 전환과 함께 지원하는 다이나믹스 365와 파워포인트, 워드와 엑셀, 원노트, 아웃룩, 팀즈 등의 오피스 365, 링크드인, 그리고 엑스박스 게임, 컴퓨터 운영체제 소프트웨어인 윈...
# Wikipedia에서 더 보기
# What is the stock symbol for Microsoft Corporation?
# The stock symbol for Microsoft Corporation is "
# MSFT." Is Microsoft a Good Stock to Buy? Determining whether Microsoft, or any stock, is a good buy requires comprehensive analysis. To evaluate its potential, users can sign up to InvestingPro, where they can assess stock price fair value and other essential metrics.
# investing.com
# 7:42
# Microsoft Stock Analysis: Buy, Hold, or Sell? | MSFT Stock AnalysisYouTube조회 수: 3570피드백
# Stock Analysis
# https://stockanalysis.com › stocks › msft
# 이 결과를 번역하세요
# Microsoft (MSFT) Stock Price & Overview4일 전 · A detailed overview of Microsoft Corporation (MSFT) stock, including …
# Day's Range: 468.78-473.34
# Previous Close: 467.68
# Open: 470.09
# Volume: 15,250,189
# MarketBeat
# https://www.marketbeat.com › stocks › NASDAQ › MSFT
# 이 결과를 번역하세요
# Microsoft MSFT stock price and analysis 심층 분석
# Microsoft
# corporation stock
# newsMicrosoft stock
# newsMicrosoft stock price
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "referrer": "origin-when-cross-origin",
#         "SystemEntropyOriginTrialToken": "A7cQcumnCpYMtO5VusikffR0WGYjWyI/y0wN/izvd92Pwty8awTPuPqSlIYk10vLdR6azJGHCZNOtmniRmPY4rwAAABeeyJvcmlnaW4iOiJodHRwczovL3d3dy5iaW5nLmNvbTo0NDMiLCJmZWF0dXJlIjoiTXNVc2VyQWdlbnRMYXVuY2hOYXZUeXBlIiwiZXhwaXJ5IjoxNzY0NzIwMDAwfQ==",
#         "ConfidenceOriginTrialToken": "Aqw360MHzRcmtEVv55zzdIWcTk2BBYHcdBAOysNJZP4qkN8M+5vUq36ITHFVst8LiX36KBZJXB8xvyBgdK2z5Q0AAAB6eyJvcmlnaW4iOiJodHRwczovL2JpbmcuY29tOjQ0MyIsImZlYXR1cmUiOiJQZXJmb3JtYW5jZU5hdmlnYXRpb25UaW1pbmdDb25maWRlbmNlIiwiZXhwaXJ5IjoxNzYwNDAwMDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=",
#         "og:description": "Bing\uc740 \uc9c0\ub2a5\uc801\uc778 \uac80\uc0c9 \uae30\ub2a5\uc740 \uc0ac\uc6a9\uc790\uac00 \uc6d0\ud558\ub294 \uc815\ubcf4\ub97c \ube60\ub974\uac8c \uac80\uc0c9\ud558\uace0 \ubcf4\uc0c1\uc744 \uc81c\uacf5\ud569\ub2c8\ub2e4.",
#         "og:site_name": "Bing",
#         "og:title": "Microsoft MSFT stock price and analysis - Bing",
#         "og:url": "https://www.bing.com/search?q=Microsoft+MSFT+stock+price+and+analysis&FORM=QBLH",
#         "fb:app_id": "3732605936979161",
#         "og:image": "http://www.bing.com/sa/simg/facebook_sharing_5.png",
#         "og:type": "website",
#         "og:image:width": "600",
#         "og:image:height": "315"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please open a trusted financial data page like Yahoo Finance or MarketBeat for Microsoft (MSFT) and provide the current stock price. Then summarize recent analyst reports or expert commentary about Microsoft's outlook and growth prospects to answer the user request comprehensively.
# ---------- MultiModalMessage (WebSurfer) ----------
# I clicked 'Yahoo Finance
# https://finance.yahoo.com › quote › MSFT
# 이 결과를 번역하세요
# Microsoft Corporation (MSFT) Stock Price, News, Quote & History
# Find the latest Microsoft Corporation (MSFT) stock quote, history, news and other vital information to help you with your stock trading and investing.
# News
# Get the latest Microsoft Corporation (MSFT) stock news and headlines to hel…
# Chart
# Interactive Chart for Microsoft Corporation (MSFT), analyze all the dat…
# Statistics
# Find out all the key statistics for Microsoft Corporation (MSFT), includin…
# ARM
# Find the latest Arm Holdings plc (ARM) stock quote, history, news and other vita…
# ORCL Oracle Corporation
# Find the latest Oracle Corporation (ORCL) stock quote, history, news and other vita…
# Historical Data
# Discover historical prices for MSFT stock on Yahoo! Finance. View daily, weekly or …'.
#
# The web browser is open to the page [Arm Holdings plc (ARM) Stock Price, News, Quote & History - Yahoo Finance](https://finance.yahoo.com/quote/ARM/).
# The viewport shows 22% of the webpage, and is positioned at the top of the page
# The following text is visible in the viewport:
#
# News
# Finance
# Sports
# More
# News
# Today's news
# US
# Politics
# World
# Weather
# Climate change
# Health
# Science
# Originals
# Newsletters
# Games
# Life
# Health
# Parenting
# Style and beauty
# Horoscopes
# Shopping
# Food
# Travel
# Autos
# Gift ideas
# Buying guides
# Best Prime Day deals
# Prime Day tech deals
# October Prime Day deals
# Entertainment
# Celebrity
# TV
# Movies
# Music
# How to Watch
# Interviews
# Videos
# Finance
# My portfolio
# Watchlists
# Markets
# News
# Videos
# Screeners
# USD
# Arm Holdings plc
# (ARM)
# Follow
# Add holdings
# Is ARM the next big buy?
# 170.24
# +2.07
# (+1.23%)
# As of 10:40:09 AM EDT. Market Open.
# 1D
# 5D
# 1M
# 6M
# YTD
# 1Y
# 5Y
# All
# Key Events
# Previous Close
# 168.16Open
# 172.06Bid
# 123.84 x 200
# Ask
# 175.00 x 100
# Day's Range
# 167.80 - 172.29Market Cap (intraday)
# 180.408BBeta (5Y Monthly)
# 4.12
# PE Ratio (TTM)
# 258.05EPS (TTM)
# 0.66Earnings Date
# Nov 5, 2025
# U.S. markets close in 5h 21m
# US
# Europe
# Asia
# Cryptocurrencies
# S&P 500
# 6,712.73+68.42(+1.03%)Dow 30
# 46,569.91+299.45(+0.65%)Nasdaq
# 22,818.63+296.93(+1.32%)Russell 2000
# 2,535.72+40.22(+1.61%)VIX
# 19.13-1.68(-8.08%)Gold
# 4,223.00+59.60(+1.43%)Portfolio
# Sign in to access your portfolio
# Sign in
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "oath:guce:consent-host": "guce.yahoo.com",
#         "title": "Arm Holdings plc (ARM) Stock Price, News, Quote & History - Yahoo Finance",
#         "description": "Find the latest Arm Holdings plc (ARM) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "keywords": "ARM, Arm Holdings plc, ARM stock chart, Arm Holdings plc stock chart, stock chart, stocks, quotes, finance",
#         "viewport": "width=device-width, initial-scale=1",
#         "theme-color": "#037B66",
#         "twitter:dnt": "on",
#         "twitter:site": "@YahooFinance",
#         "twitter:description": "Find the latest Arm Holdings plc (ARM) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "twitter:title": "Arm Holdings plc (ARM) Stock Price, News, Quote & History - Yahoo Finance",
#         "twitter:image": "https://pinhole.finance.yahoo.com/chart/ARM/__screenshot",
#         "twitter:image:src": "https://pinhole.finance.yahoo.com/chart/ARM/__screenshot",
#         "fb:app_id": "458584288257241",
#         "fb:pages": "458584288257241",
#         "ogImg": "https://pinhole.finance.yahoo.com/chart/ARM/__screenshot",
#         "og:description": "Find the latest Arm Holdings plc (ARM) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "og:title": "Arm Holdings plc (ARM) Stock Price, News, Quote & History - Yahoo Finance",
#         "og:url": "https://finance.yahoo.com/quote/ARM/",
#         "og:site_name": "Yahoo Finance",
#         "al:ios:app_store_id": "328412701",
#         "al:ios:app_name": "Yahoo Finance",
#         "al:android:url": "intent://#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.client.android.finance;S.browser_fallback_url=https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdetails%3Fid%3Dcom.yahoo.mobile.client.android.finance;end",
#         "al:android:app_name": "Yahoo Finance",
#         "al:android:package": "com.yahoo.mobile.client.android.finance",
#         "apple-itunes-app": "app-id=328412701, affiliate-data=ct=us.fin.mbl.smart-banner&pt=9029, app-argument=https://yfinance.onelink.me/3068494570?pid=SmartBanner&c=US_Acquisition_YMktg_337__&af_sub1=Acquisition&af_sub2=US_YMktg&af_sub3=&af_sub4=100000591&af_sub5=YahooFinanceApp__SmartBanner_",
#         "conf:cjs:consent-event-listener": "true"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
#
# Home affordability calculator
# Insurance
# Find car insurance
# Types of car insurance
# Find life insurance
# Taxes
# Tax refund status
# How to file
# Tax extension
# Child tax credit
# Student loans
# Federal vs. private
# How to apply
# FAFSA 2026-27
# Student loan assistance
# Personal loans
# Best personal loans
# Improve credit score
# How to get approved
# Videos
# Latest
# Editor's picks
# Trending stocks
# Investing insights
# Live shows
# Morning Brief
# Catalysts
# Wealth
# Market Domination
# Asking for a Trend
# Opening Bid
# Video podcasts
# Stocks in Translation
# Trader Talk
# Warrior Money
# Living Not So Fabulously
# The Big Idea
# Financial Freestyle
# Yahoo Finance Sports Report
# Decoding Retirement
# Watch now
# Summary
# News
# Chart
# Conversations
# Statistics
# Historical Data
# Profile
# Financials
# Analysis
# Options
# Holders
# Sustainability
# NasdaqGS - Nasdaq Real Time Price
# •
# USD
# Microsoft Corporation
# (MSFT)
# Follow
# Add holdings
# Time to buy MSFT?
# 515.21
# +1.64
# (+0.32%)
# As of 10:40:40 AM EDT. Market Open.
# 1D
# 5D
# 1M
# 6M
# YTD
# 1Y
# 5Y
# All
# Key Events
# Previous Close
# 513.57Open
# 514.55Bid
# 514.52 x 100
# Ask
# 518.97 x 400
# Day's Range
# 513.68 - 517.18Market Cap (intraday)
# 3.83TBeta (5Y Monthly)
# 1.02
# PE Ratio (TTM)
# 37.72EPS (TTM)
# 13.66Earnings Date
# Oct 29, 2025
# U.S. markets close in 5h 20m
# US
# Europe
# Asia
# Cryptocurrencies
# S&P 500
# 6,713.02+68.71(+1.03%)Dow 30
# 46,573.11+302.65(+0.65%)Nasdaq
# 22,820.42+298.72(+1.33%)Russell 2000
# 2,535.17+39.67(+1.59%)VIX
# 19.14
# -1.67(-8.02%)Gold
# 4,224.00
# +60.60(+1.46%)Recently viewed
# ARM
# Arm Holdings plc
# 170.06+1.90(+1.13%)Portfolio
# Sign in to access your portfolio
#
# The following metadata was extracted from the webpage:
#
# {
#     "meta_tags": {
#         "oath:guce:consent-host": "guce.yahoo.com",
#         "title": "Microsoft Corporation (MSFT) Stock Price, News, Quote & History - Yahoo Finance",
#         "description": "Find the latest Microsoft Corporation (MSFT) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "keywords": "MSFT, Microsoft Corporation, MSFT stock chart, Microsoft Corporation stock chart, stock chart, stocks, quotes, finance",
#         "viewport": "width=device-width, initial-scale=1",
#         "theme-color": "#037B66",
#         "twitter:dnt": "on",
#         "twitter:site": "@YahooFinance",
#         "twitter:description": "Find the latest Microsoft Corporation (MSFT) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "twitter:title": "Microsoft Corporation (MSFT) Stock Price, News, Quote & History - Yahoo Finance",
#         "twitter:image": "https://pinhole.finance.yahoo.com/chart/MSFT/__screenshot",
#         "twitter:image:src": "https://pinhole.finance.yahoo.com/chart/MSFT/__screenshot",
#         "fb:app_id": "458584288257241",
#         "fb:pages": "458584288257241",
#         "ogImg": "https://pinhole.finance.yahoo.com/chart/MSFT/__screenshot",
#         "og:description": "Find the latest Microsoft Corporation (MSFT) stock quote, history, news and other vital information to help you with your stock trading and investing.",
#         "og:title": "Microsoft Corporation (MSFT) Stock Price, News, Quote & History - Yahoo Finance",
#         "og:url": "https://finance.yahoo.com/quote/MSFT/",
#         "og:site_name": "Yahoo Finance",
#         "al:ios:app_store_id": "328412701",
#         "al:ios:app_name": "Yahoo Finance",
#         "al:android:url": "intent://#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.client.android.finance;S.browser_fallback_url=https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdetails%3Fid%3Dcom.yahoo.mobile.client.android.finance;end",
#         "al:android:app_name": "Yahoo Finance",
#         "al:android:package": "com.yahoo.mobile.client.android.finance",
#         "apple-itunes-app": "app-id=328412701, affiliate-data=ct=us.fin.mbl.smart-banner&pt=9029, app-argument=https://yfinance.onelink.me/3068494570?pid=SmartBanner&c=US_Acquisition_YMktg_337__&af_sub1=Acquisition&af_sub2=US_YMktg&af_sub3=&af_sub4=100000591&af_sub5=YahooFinanceApp__SmartBanner_",
#         "conf:cjs:consent-event-listener": "true"
#     }
# }
#
# Here is a screenshot of the page.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please find and summarize recent analyst reports, expert commentary, or credible news articles discussing Microsoft's future stock outlook and prospects, in addition to confirming the current stock price you found.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# ...
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# Model gpt-4.1-mini not found. Using cl100k_base encoding.
# ---------- TextMessage (WebSurfer) ----------
# The Yahoo Finance webpage provides comprehensive financial information and recent news about Microsoft Corporation (MSFT). As of the latest market update, Microsoft's stock price is $515.41 with a slight increase of +0.36%, and its market capitalization stands at $3.83 trillion. The company's latest financial highlights reveal strong year-over-year growth, including a 12% revenue increase reaching $69.6 billion and a 10% EPS rise to $3.23. Microsoft’s cloud segment, especially Azure, is a key growth driver with a 34% revenue surge. The company is also deeply invested in AI integration through its partnership with OpenAI and AI-enhanced products like Copilot, aiming for high-margin enterprise deals and expansive AI-driven revenue growth projected to reach over $200 billion by 2029.
#
# The page also features detailed stock statistics, including a trailing P/E of 37.72 and a forward dividend yield of 0.71%, and provides analysts' insights that generally rate MSFT as an outperform with a price target averaging around $620.74. Microsoft's business is organized into three major segments: Productivity and Business Processes (including Microsoft 365 and LinkedIn), Intelligent Cloud (Azure and server products), and Personal Computing (Windows, Devices, Gaming, and advertising). The company is praised for its strong AI ecosystem, combining cloud infrastructure, software services, and AI applications, making it a top long-term investment choice with stable and substantial growth prospects.
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# 마이크로소프트(MSFT)의 현재 주가는 약 515달러 선이며, 시가총액은 약 3.83조 달러에 달합니다. 최근 재무 성과도 매우 긍정적인데, 연간 매출은 12% 증가하여 696억 달러에 달했고, 주당순이익(EPS)도 10% 상승한 3.23달러를 기록했습니다. 특히 클라우드 사업 부문인 애저(Azure)의 매출이 34% 급증하며 회사 성장의 핵심 동력이 되고 있습니다.
#
# 또한 마이크로소프트는 오픈AI와의 협력을 통해 인공지능(AI) 기술을 적극 도입 중이며, AI 통합 제품군인 코파일럿 등을 통해 고수익의 엔터프라이즈 시장 공략에 나서고 있습니다. 전문가들은 MSFT 주식을 ‘아웃퍼폼(시장 대비 우수)’으로 평가하며, 평균 목표주가로 약 620달러를 제시하고 있습니다.
#
# 요약하면, 마이크로소프트는 클라우드, AI 등 미래 성장 산업에서 확고한 입지를 다지고 있어 장기적인 주식 투자에 안정적이면서도 높은 성장 가능성을 가진 기업으로 평가받고 있습니다. 투자 관점에서 현재 주가는 견고하며, 앞으로도 긍정적인 전망이 기대됩니다.
# messages=[TextMessage(id='81fd1dd8-3086-47e6-915c-f6128203adf2', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 15, 14, 39, 10, 683665, tzinfo=datetime.timezone.utc), content='마이크로소프트 현재 주가와 전망에 대해 알려줘', type='TextMessage'), TextMessage(id='21591f6c-f5e2-40cd-811c-7b3db33d2789', source='MagenticOneOrchestrator', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 15, 14, 39, 24, 426371, tzinfo=datetime.timezone.utc), content='\nWe are working to address the following user request:\n\n마이크로소프트 현재 주가와 전망에 대해 알려줘\n\n\nTo answer this request we have assembled the following team:\n\nFileSurfer: An agent that can handle local files.\nWebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.\nCoder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.\nComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).\n\n\nHere is an initial fact sheet to consider:\n\n1. GIVEN OR VERIFIED FACTS  \n- The request asks for the current stock price ("현재 주가") of Microsoft ("마이크로소프트") and its outlook ("전망").  \n- No specific numbers or dates are provided in the request itself.\n\n2. FACTS TO LOOK UP  \n- The current stock price of Microsoft (ticker symbol MSFT), which can be found on financial news websites such as Yahoo Finance, Google Finance, Bloomberg, or stock exchange official sites (e.g., NASDAQ).  \n- Recent analyst reports, news, and forecasts about Microsoft\'s future outlook, which might be found on financial analysis platforms such as Bloomberg, Morningstar, Seeking Alpha, or reports from major investment banks or research firms.\n\n3. FACTS TO DERIVE  \n- Potential short- to mid-term stock price trends or outlook based on recent performance, market conditions, and company fundamentals.  \n- Interpretation of how broader market or sector trends impact Microsoft\'s prospects.\n\n4. EDUCATED GUESSES  \n- Microsoft is a major technology company with a diversified product portfolio including cloud computing (Azure), software (Windows, Office), gaming (Xbox), and enterprise services. Its stock price is generally influenced by these factors as well as macroeconomic conditions.  \n- The outlook might consider the increasing cloud market demand and competitive pressures.  \n- Given the dynamic nature of stock markets, the outlook often includes some degree of uncertainty.\n\n\nHere is the plan to follow as best as possible:\n\n- Instruct WebSurfer to look up the current stock price of Microsoft (MSFT) on a reliable financial website (e.g., Yahoo Finance or Google Finance).  \n- Ask WebSurfer to gather recent analyst reports, news articles, and expert commentary regarding Microsoft’s future outlook and growth prospects.  \n- Have WebSurfer summarize the key points about Microsoft’s market position, recent financial performance, and relevant industry trends affecting its outlook.  \n- Synthesize the gathered current price and outlook information into a concise response in Korean, as the original request language is Korean.\n', type='TextMessage'), TextMessage(id='be3cb89a-84e5-4950-8ca2-bc0614d6f2d8', source='MagenticOneOrchestrator', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 15, 14, 39, 29, 967893, tzinfo=datetime.timezone.utc), content='Please look up the current stock price of Microsoft (MSFT) on a reliable financial website and find recent analyst or expert commentary regarding Microsoft’s s ...
